# %% [markdown]
# # Classification of handwritten digits using various neural network models with PyTorch
# * Multinomial classification task of images of handwritten digits (10 classes).
# * The database has a training set of 60k examples, and a test set of 10k examples, each image is of 28x28 pixels size.
# * The MNIST ("Modified National Institute of Standards and Technology") is the “hello world” dataset for computer vision. Since its release in 1999, this classic dataset of handwritten images has served as the basis for benchmarking classification algorithms.

# %% [markdown]
# ## Model setup

# %% [markdown]
# Before we start we need to load libraries and setup the model parameters

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14})

model_args = {}
# random seed
model_args['seed'] = 123
# we will use batch size of 128 in Stochastic Gradient Descent (SGD) optimization of the network
model_args['batch_size'] = 128
# learning rate is how fast it will descend
model_args['lr'] = .05
# SGD momentum (default: .5) momentum is a moving average of gradients (it helps to keep direction)
model_args['momentum'] = .5
# the number of epochs is the number of times you go through the full dataset
model_args['epochs'] = 50
# logging frequency
model_args['log_interval'] = 100

# %% [markdown]
# Let's start with loading the dataset and check how it looks like
# > **In case of problems with downloading dataset via torchvison please use the second method**

# %%
# load the MINST dataset via torchvision
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.1307,), (0.3081,))])
mnist_train = datasets.MNIST('../data', train=True, download=True, transform=transform)
# we divide this data into training and validation subsets
train_subset, validation_subset = torch.utils.data.random_split(mnist_train, [50000, 10000])
test_subset = datasets.MNIST('../data', train=False, download=True, transform=transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ../data\MNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:02<00:00, 3588193.37it/s]
# Extracting ../data\MNIST\raw\train-images-idx3-ubyte.gz to ../data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ../data\MNIST\raw\train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 244532.33it/s]
# Extracting ../data\MNIST\raw\train-labels-idx1-ubyte.gz to ../data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ../data\MNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 2013910.47it/s]
# Extracting ../data\MNIST\raw\t10k-images-idx3-ubyte.gz to ../data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ../data\MNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 4539082.38it/s]
# Extracting ../data\MNIST\raw\t10k-labels-idx1-ubyte.gz to ../data\MNIST\raw

# %% [markdown]
# Second method: directly download tar.gz archive

# %%
# # alternatively just download MNIST.tar.gz archive
# !wget www.di.ens.fr/~lelarge/MNIST.tar.gz
# !tar -zxvf MNIST.tar.gz
#
# transform = transforms.Compose([transforms.ToTensor(),
#                               transforms.Normalize((0.1307,), (0.3081,))])
# mnist_train = datasets.MNIST('./', train=True, download=False, transform=transform)
# # we divide this data into training and validation subsets
# train_subset, validation_subset = torch.utils.data.random_split(mnist_train, [50000, 10000])
# test_subset = datasets.MNIST('./', train=False, download=False, transform=transform)

# %%
# define dataloaders
loader_kwargs = {'batch_size': model_args['batch_size'],
                 'num_workers': 2,
                 'pin_memory': True,
                 'shuffle': True}
train_loader = torch.utils.data.DataLoader(train_subset, **loader_kwargs)
validation_loader = torch.utils.data.DataLoader(validation_subset, **loader_kwargs)
test_loader = torch.utils.data.DataLoader(test_subset, **loader_kwargs)

# %% [markdown]
# Plot sample images

# %%
print(len(train_subset))
print(len(validation_subset))
print(len(test_subset)) # we have data already divided into train & validation & test subsets
print(len(train_loader)) # no of train batches
example_number = 123
print(train_subset[example_number][0][0].shape) # single item shape

fig, axs = plt.subplots(5, 5, figsize=(7,7), tight_layout=True)
for i in range(5):
    for j in range(5):
        axs[i,j].imshow(train_subset[example_number+i*5+j][0].reshape(28,28), cmap='gray')
        axs[i,j].set_title(train_subset[example_number+i*5+j][1])
# Out:
# 50000
# 10000
# 10000
# 391
# torch.Size([28, 28])

# %% [markdown]
# Let's now construct the NN models:
# - we start with simplest single layer **perceptron** with *softmax* activation,
# - then test **deep** network with some (fully-connected) *hidden* layers,
# - and finally setup deep **convolutional neural network**.

# %%
class Perceptron(nn.Module):
    # this defines the structure of the Perceptron model
    def __init__(self):
        super(Perceptron, self).__init__()
        # fully connected layer
        self.fc = nn.Linear(28*28, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc(x)
        return F.log_softmax(x, dim=1) # note that dim=0 is the number of samples in batch

class Deep(nn.Module):
    # this defines the structure of the Perceptron model
    def __init__(self):
        super(Deep, self).__init__()
        # fully connected layers
        self.fc1 = nn.Linear(28*28, 20)
        self.fc2 = nn.Linear(20, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = F.relu(x)
        # hidden layer
        x = self.fc2(x)
        return F.log_softmax(x, dim=1) # note that dim=0 is the number of samples in batch

class CNN(nn.Module):
    # this defines the structure of the CNN model
    def __init__(self):
        super(CNN, self).__init__()
        # convolutional layer with 2 kernels of size 5x5
        self.conv1 = nn.Conv2d(1, 2, kernel_size=5)
        # 4 kernels of size 5x5
        self.conv2 = nn.Conv2d(2, 4, kernel_size=5)
        # 2D dropout
        self.conv2_drop = nn.Dropout2d()
        # fully connected layers
        self.fc1 = nn.Linear(64, 20)
        self.fc2 = nn.Linear(20, 10)

    def forward(self, x):
        # 1st layers group
        x = self.conv1(x) # resulting in 2 feature maps each of size 24x24
        x = F.max_pool2d(x, 2) # downsizing each map to 12x12
        x = F.relu(x) # standard (in CNNs) ReLU activation
        # 2nd group
        x = self.conv2(x) # resulting in 4 feature maps each of size 8x8
        # x = self.conv2_drop(x) # regularization
        x = F.max_pool2d(x, 2) # downsizing each map to 4x4
        x = F.relu(x)
        # fully connected layers
        x = x.view(-1, 64) # 4 maps of 4x4 size gives 64 numbers
        x = self.fc1(x) # 64 -> 20
        x = F.relu(x)
        x = F.dropout(x, training=self.training) # dropout is a type of regularization
        x = self.fc2(x) # 20 -> 10
        # softmax (multinomial classification) gives probabilities of each class
        return F.log_softmax(x, dim=1) # note that dim=0 is the number of samples in batch

# %% [markdown]
# And define training, testing, and plotting utils:

# %%
def train(model, device, train_loader, optimizer, epoch_number):
    model.train()
    train_loss = 0.
    # get subsequent batches over the data in a given epoch
    for batch_idx, (data, target) in enumerate(train_loader):
        # send data tensors to GPU (or CPU)
        data, target = data.to(device), target.to(device)
        # this will zero out the gradients for this batch
        optimizer.zero_grad()
        # this will execute the forward() function
        output = model(data)
        # calculate the negative-log-likelihood loss
        loss = F.nll_loss(output, target, reduction='mean')
        # backpropagate the loss
        loss.backward()
        # update the model weights (with assumed learning rate)
        optimizer.step()
        if batch_idx % model_args['log_interval'] == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch_number, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
        train_loss += loss.item()
    train_loss /= len(train_loader)
    print('\nTrain set: Average loss: {:.4f}'.format(train_loss))
    return train_loss

def test(model, device, test_loader, message):
    model.eval()
    test_loss = 0.
    correct = 0
    # this is just inference, we don't need to calculate gradients
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            # calculate and sum up batch loss
            test_loss += F.nll_loss(output, target, reduction='mean')
            # get the index of class with the max log-probability
            prediction = output.argmax(dim=1)
            # item() returns value of the given tensor
            correct += prediction.eq(target).sum().item()
    test_loss /= len(test_loader)
    print('{}: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        message, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss.cpu()

def plot_loss(train_loss, validation_loss, title):
    plt.grid(True)
    plt.xlabel("subsequent epochs")
    plt.ylabel('average loss')
    plt.plot(range(1, len(train_loss)+1), train_loss, 'o-', label='training')
    plt.plot(range(1, len(validation_loss)+1), validation_loss, 'o-', label='validation')
    plt.legend()
    plt.title(title)
    plt.show()

# %% [markdown]
# ## Experiments

# %% [markdown]
# 1. At first let's test the single-layer *Perceptron* model

# %%
# the single-layer *Perceptron* model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Perceptron().to(device)

optimizer = optim.SGD(model.parameters(), lr=model_args['lr'], momentum=model_args['momentum'])
#optimizer = optim.Adadelta(model.parameters(), lr=model_args['lr'])

torch.manual_seed(model_args['seed'])
train_loss = []
validation_loss = []
for epoch_number in range(1, model_args['epochs'] + 1):
    train_loss.append(train(model, device, train_loader, optimizer, epoch_number))
    validation_loss.append(test(model, device, validation_loader, 'Validation set'))

test(model, device, test_loader, 'Test set')
plot_loss(train_loss, validation_loss, 'Perceptron model')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.519022
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 0.285766
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.347265
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.287127
#
# Train set: Average loss: 0.3742
# Validation set: Average loss: 0.3133, Accuracy: 9103/10000 (91%)
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.307731
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.235419
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.446569
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.281081
#
# Train set: Average loss: 0.3010
# Validation set: Average loss: 0.3160, Accuracy: 9116/10000 (91%)
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.200514
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.293091
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.195685
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.306887
#
# Train set: Average loss: 0.2887
# Validation set: Average loss: 0.3017, Accuracy: 9166/10000 (92%)
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.229252
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.278134
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.372970
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.166284
#
# Train set: Average loss: 0.2816
# Validation set: Average loss: 0.3070, Accuracy: 9187/10000 (92%)
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.179229
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.184815
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.367987
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.211982
#
# Train set: Average loss: 0.2768
# Validation set: Average loss: 0.2911, Accuracy: 9211/10000 (92%)
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.280396
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.200067
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.214285
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.378621
#
# Train set: Average loss: 0.2721
# Validation set: Average loss: 0.3085, Accuracy: 9193/10000 (92%)
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.278824
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.195794
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.337662
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.297242
#
# Train set: Average loss: 0.2699
# Validation set: Average loss: 0.2951, Accuracy: 9215/10000 (92%)
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.249333
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.174454
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.217357
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.257045
#
# Train set: Average loss: 0.2673
# Validation set: Average loss: 0.2997, Accuracy: 9193/10000 (92%)
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.205865
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.329973
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.177293
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.311675
#
# Train set: Average loss: 0.2647
# Validation set: Average loss: 0.3010, Accuracy: 9179/10000 (92%)
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.148993
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.263202
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.249734
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.285236
#
# Train set: Average loss: 0.2634
# Validation set: Average loss: 0.2975, Accuracy: 9176/10000 (92%)
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.264264
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.288136
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.238669
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.323257
#
# Train set: Average loss: 0.2620
# Validation set: Average loss: 0.2907, Accuracy: 9201/10000 (92%)
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.278002
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.292011
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.211475
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.103541
#
# Train set: Average loss: 0.2599
# Validation set: Average loss: 0.2910, Accuracy: 9226/10000 (92%)
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.239862
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.189413
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.140801
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.257801
#
# Train set: Average loss: 0.2580
# Validation set: Average loss: 0.2981, Accuracy: 9174/10000 (92%)
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.280904
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.146983
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.198057
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.251774
#
# Train set: Average loss: 0.2568
# Validation set: Average loss: 0.3076, Accuracy: 9175/10000 (92%)
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.327234
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.274035
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.208429
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.223793
#
# Train set: Average loss: 0.2571
# Validation set: Average loss: 0.2951, Accuracy: 9215/10000 (92%)
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.279216
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.262294
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.311541
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.560763
#
# Train set: Average loss: 0.2555
# Validation set: Average loss: 0.2948, Accuracy: 9189/10000 (92%)
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.320099
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.180004
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.234437
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.218930
#
# Train set: Average loss: 0.2542
# Validation set: Average loss: 0.3028, Accuracy: 9205/10000 (92%)
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.202689
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.186178
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.365589
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.363518
#
# Train set: Average loss: 0.2528
# Validation set: Average loss: 0.2973, Accuracy: 9214/10000 (92%)
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.228891
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.218172
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.138585
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.226456
#
# Train set: Average loss: 0.2520
# Validation set: Average loss: 0.3038, Accuracy: 9181/10000 (92%)
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.210097
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.424981
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.308770
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.372325
#
# Train set: Average loss: 0.2517
# Validation set: Average loss: 0.2949, Accuracy: 9209/10000 (92%)
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.245293
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.245511
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.207047
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.125433
#
# Train set: Average loss: 0.2510
# Validation set: Average loss: 0.3021, Accuracy: 9218/10000 (92%)
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.400917
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.396550
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.330535
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.185714
#
# Train set: Average loss: 0.2496
# Validation set: Average loss: 0.3058, Accuracy: 9176/10000 (92%)
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.214530
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.383623
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.265024
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.328873
#
# Train set: Average loss: 0.2492
# Validation set: Average loss: 0.3045, Accuracy: 9199/10000 (92%)
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.255512
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.277266
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.213545
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.151730
#
# Train set: Average loss: 0.2490
# Validation set: Average loss: 0.3040, Accuracy: 9168/10000 (92%)
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.171827
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.356886
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.166613
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.306738
#
# Train set: Average loss: 0.2479
# Validation set: Average loss: 0.2963, Accuracy: 9200/10000 (92%)
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.244379
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.202293
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.422559
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.158325
#
# Train set: Average loss: 0.2484
# Validation set: Average loss: 0.2962, Accuracy: 9206/10000 (92%)
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.207196
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.366179
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.165553
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.263782
#
# Train set: Average loss: 0.2476
# Validation set: Average loss: 0.3020, Accuracy: 9198/10000 (92%)
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.208241
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.231386
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.223544
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.279308
#
# Train set: Average loss: 0.2464
# Validation set: Average loss: 0.3085, Accuracy: 9194/10000 (92%)
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.314213
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.406767
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.228262
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.324406
#
# Train set: Average loss: 0.2466
# Validation set: Average loss: 0.3228, Accuracy: 9192/10000 (92%)
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.200536
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.417440
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.282839
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.361488
#
# Train set: Average loss: 0.2455
# Validation set: Average loss: 0.3030, Accuracy: 9168/10000 (92%)
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.210046
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.285908
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.325276
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.194069
#
# Train set: Average loss: 0.2453
# Validation set: Average loss: 0.3010, Accuracy: 9200/10000 (92%)
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.208011
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.228607
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.232500
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.115729
#
# Train set: Average loss: 0.2445
# Validation set: Average loss: 0.2991, Accuracy: 9191/10000 (92%)
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.330867
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.320040
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.188845
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.361654
#
# Train set: Average loss: 0.2450
# Validation set: Average loss: 0.3049, Accuracy: 9202/10000 (92%)
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.288873
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.369296
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.215507
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.255251
#
# Train set: Average loss: 0.2442
# Validation set: Average loss: 0.3000, Accuracy: 9227/10000 (92%)
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.227726
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.304565
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.343934
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.304579
#
# Train set: Average loss: 0.2430
# Validation set: Average loss: 0.3122, Accuracy: 9178/10000 (92%)
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.194568
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.234474
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.199434
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.175803
#
# Train set: Average loss: 0.2442
# Validation set: Average loss: 0.3085, Accuracy: 9189/10000 (92%)
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.184891
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.274546
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.185890
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.352123
#
# Train set: Average loss: 0.2428
# Validation set: Average loss: 0.3032, Accuracy: 9200/10000 (92%)
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.283182
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.304625
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.252448
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.269061
#
# Train set: Average loss: 0.2434
# Validation set: Average loss: 0.3092, Accuracy: 9169/10000 (92%)
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.313440
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.400386
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.161157
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.232439
#
# Train set: Average loss: 0.2432
# Validation set: Average loss: 0.2999, Accuracy: 9218/10000 (92%)
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.155122
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.396773
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.170908
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.160325
#
# Train set: Average loss: 0.2421
# Validation set: Average loss: 0.3125, Accuracy: 9183/10000 (92%)
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.270567
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.171047
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.249287
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.164712
#
# Train set: Average loss: 0.2418
# Validation set: Average loss: 0.3151, Accuracy: 9174/10000 (92%)
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.170399
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.335883
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.194144
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.318772
#
# Train set: Average loss: 0.2414
# Validation set: Average loss: 0.2992, Accuracy: 9207/10000 (92%)
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.246768
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.157841
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.353339
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.226781
#
# Train set: Average loss: 0.2408
# Validation set: Average loss: 0.3021, Accuracy: 9223/10000 (92%)
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.282871
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.120979
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.188468
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.192642
#
# Train set: Average loss: 0.2414
# Validation set: Average loss: 0.3081, Accuracy: 9154/10000 (92%)
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.314072
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.211162
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.266081
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.217813
#
# Train set: Average loss: 0.2415
# Validation set: Average loss: 0.3085, Accuracy: 9183/10000 (92%)
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.382696
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.151036
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.117151
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.214742
#
# Train set: Average loss: 0.2405
# Validation set: Average loss: 0.3118, Accuracy: 9171/10000 (92%)
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.222707
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.274467
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.162592
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.200963
#
# Train set: Average loss: 0.2410
# Validation set: Average loss: 0.3086, Accuracy: 9180/10000 (92%)
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.239556
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.283262
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.132935
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.152184
#
# Train set: Average loss: 0.2399
# Validation set: Average loss: 0.3068, Accuracy: 9179/10000 (92%)
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.227776
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.175168
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.155536
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.295921
#
# Train set: Average loss: 0.2394
# Validation set: Average loss: 0.3077, Accuracy: 9201/10000 (92%)
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.354087
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.420565
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.265074
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.240828
#
# Train set: Average loss: 0.2400
# Validation set: Average loss: 0.3052, Accuracy: 9188/10000 (92%)
# Test set: Average loss: 0.2911, Accuracy: 9228/10000 (92%)

# %% [markdown]
# 2. Now add a hidden layer to the *Perceptron* and evaluate the *Deep* model

# %%
# Now add a hidden layer to the *Perceptron* and evaluate the *Deep* model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Deep().to(device)

# optimizer = optim.SGD(model.parameters(),
#                       lr=model_args['lr'],
#                       momentum=model_args['momentum'],
#                       weight_decay=1.e-3)

#Train set: Average loss: 0.0809
# Validation set: Average loss: 0.1434, Accuracy: 9569/10000 (96%)
# Test set: Average loss: 0.1343, Accuracy: 9591/10000 (96%)

# optimizer = optim.Adadelta(model.parameters(), lr=model_args['lr'])

# Train set: Average loss: 0.1439
# Validation set: Average loss: 0.1732, Accuracy: 9482/10000 (95%)
# Test set: Average loss: 0.1610, Accuracy: 9521/10000 (95%)

optimizer = optim.SGD(model.parameters(), lr=model_args['lr'], momentum=model_args['momentum'], weight_decay=1e-3)
# Train set: Average loss: 0.0817
# Validation set: Average loss: 0.1344, Accuracy: 9595/10000 (96%)
# Test set: Average loss: 0.1279, Accuracy: 9621/10000 (96%)


torch.manual_seed(model_args['seed'])
train_loss = []
validation_loss = []
for epoch_number in range(1, model_args['epochs'] + 1):
    train_loss.append(train(model, device, train_loader, optimizer, epoch_number))
    validation_loss.append(test(model, device, validation_loader, 'Validation set'))

test(model, device, test_loader, 'Test set')
plot_loss(train_loss, validation_loss, 'Deep model')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.334795
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 0.455258
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.317217
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.395783
#
# Train set: Average loss: 0.3943
# Validation set: Average loss: 0.2647, Accuracy: 9234/10000 (92%)
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.287506
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.193757
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.184720
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.126946
#
# Train set: Average loss: 0.2325
# Validation set: Average loss: 0.2169, Accuracy: 9365/10000 (94%)
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.288629
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.215816
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.105378
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.086461
#
# Train set: Average loss: 0.1931
# Validation set: Average loss: 0.1970, Accuracy: 9412/10000 (94%)
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.175018
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.169970
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.247408
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.173623
#
# Train set: Average loss: 0.1701
# Validation set: Average loss: 0.1883, Accuracy: 9445/10000 (94%)
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.154932
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.110648
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.150580
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.157040
#
# Train set: Average loss: 0.1545
# Validation set: Average loss: 0.1732, Accuracy: 9462/10000 (95%)
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.160257
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.159058
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.154713
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.163077
#
# Train set: Average loss: 0.1449
# Validation set: Average loss: 0.1643, Accuracy: 9512/10000 (95%)
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.196523
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.099837
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.088719
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.121742
#
# Train set: Average loss: 0.1369
# Validation set: Average loss: 0.1598, Accuracy: 9522/10000 (95%)
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.095429
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.072475
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.079065
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.055156
#
# Train set: Average loss: 0.1305
# Validation set: Average loss: 0.1569, Accuracy: 9515/10000 (95%)
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.074401
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.060326
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.144901
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.132938
#
# Train set: Average loss: 0.1247
# Validation set: Average loss: 0.1523, Accuracy: 9557/10000 (96%)
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.111293
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.065720
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.073127
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.102349
#
# Train set: Average loss: 0.1214
# Validation set: Average loss: 0.1595, Accuracy: 9529/10000 (95%)
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.108384
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.049158
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.126889
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.119010
#
# Train set: Average loss: 0.1172
# Validation set: Average loss: 0.1489, Accuracy: 9560/10000 (96%)
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.092449
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.174290
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.117096
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.145106
#
# Train set: Average loss: 0.1143
# Validation set: Average loss: 0.1517, Accuracy: 9547/10000 (95%)
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.067872
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.125565
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.102277
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.160961
#
# Train set: Average loss: 0.1112
# Validation set: Average loss: 0.1408, Accuracy: 9567/10000 (96%)
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.062181
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.124763
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.116239
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.065517
#
# Train set: Average loss: 0.1094
# Validation set: Average loss: 0.1420, Accuracy: 9578/10000 (96%)
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.145331
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.127091
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.119902
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.085013
#
# Train set: Average loss: 0.1069
# Validation set: Average loss: 0.1434, Accuracy: 9586/10000 (96%)
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.177512
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.154348
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.115807
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.068671
#
# Train set: Average loss: 0.1049
# Validation set: Average loss: 0.1439, Accuracy: 9580/10000 (96%)
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.127859
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.058698
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.111580
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.122564
#
# Train set: Average loss: 0.1032
# Validation set: Average loss: 0.1455, Accuracy: 9556/10000 (96%)
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.065339
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.134919
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.182755
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.086269
#
# Train set: Average loss: 0.1016
# Validation set: Average loss: 0.1392, Accuracy: 9587/10000 (96%)
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.058604
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.071526
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.075516
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.077387
#
# Train set: Average loss: 0.1002
# Validation set: Average loss: 0.1586, Accuracy: 9573/10000 (96%)
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.156737
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.111629
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.078719
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.048882
#
# Train set: Average loss: 0.0989
# Validation set: Average loss: 0.1376, Accuracy: 9588/10000 (96%)
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.045870
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.151178
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.102697
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.094573
#
# Train set: Average loss: 0.0971
# Validation set: Average loss: 0.1528, Accuracy: 9528/10000 (95%)
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.187166
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.074851
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.060643
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.101409
#
# Train set: Average loss: 0.0975
# Validation set: Average loss: 0.1391, Accuracy: 9593/10000 (96%)
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.088647
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.065015
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.069405
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.152584
#
# Train set: Average loss: 0.0954
# Validation set: Average loss: 0.1441, Accuracy: 9560/10000 (96%)
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.045593
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.139213
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.040567
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.054373
#
# Train set: Average loss: 0.0948
# Validation set: Average loss: 0.1410, Accuracy: 9571/10000 (96%)
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.063209
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.083553
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.079241
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.074041
#
# Train set: Average loss: 0.0934
# Validation set: Average loss: 0.1412, Accuracy: 9574/10000 (96%)
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.060728
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.059397
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.126223
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.133010
#
# Train set: Average loss: 0.0926
# Validation set: Average loss: 0.1390, Accuracy: 9586/10000 (96%)
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.075872
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.038329
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.079395
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.134284
#
# Train set: Average loss: 0.0915
# Validation set: Average loss: 0.1408, Accuracy: 9569/10000 (96%)
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.120373
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.120777
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.055538
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.086324
#
# Train set: Average loss: 0.0913
# Validation set: Average loss: 0.1442, Accuracy: 9548/10000 (95%)
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.059000
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.080790
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.071727
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.135228
#
# Train set: Average loss: 0.0904
# Validation set: Average loss: 0.1492, Accuracy: 9561/10000 (96%)
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.063689
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.050465
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.081212
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.078379
#
# Train set: Average loss: 0.0897
# Validation set: Average loss: 0.1389, Accuracy: 9577/10000 (96%)
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.074646
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.114663
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.163830
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.171746
#
# Train set: Average loss: 0.0888
# Validation set: Average loss: 0.1384, Accuracy: 9593/10000 (96%)
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.069539
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.030574
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.041167
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.089117
#
# Train set: Average loss: 0.0888
# Validation set: Average loss: 0.1420, Accuracy: 9562/10000 (96%)
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.083779
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.076308
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.053708
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.134492
#
# Train set: Average loss: 0.0886
# Validation set: Average loss: 0.1400, Accuracy: 9582/10000 (96%)
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.044013
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.108039
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.054585
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.074367
#
# Train set: Average loss: 0.0883
# Validation set: Average loss: 0.1450, Accuracy: 9570/10000 (96%)
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.057770
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.098154
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.044284
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.088268
#
# Train set: Average loss: 0.0872
# Validation set: Average loss: 0.1376, Accuracy: 9578/10000 (96%)
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.063153
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.122904
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.089811
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.096573
#
# Train set: Average loss: 0.0860
# Validation set: Average loss: 0.1418, Accuracy: 9577/10000 (96%)
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.079333
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.151840
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.055130
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.090238
#
# Train set: Average loss: 0.0859
# Validation set: Average loss: 0.1366, Accuracy: 9595/10000 (96%)
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.058512
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.099770
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.107110
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.049985
#
# Train set: Average loss: 0.0858
# Validation set: Average loss: 0.1418, Accuracy: 9572/10000 (96%)
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.027797
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.035844
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.025347
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.104938
#
# Train set: Average loss: 0.0858
# Validation set: Average loss: 0.1457, Accuracy: 9564/10000 (96%)
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.136308
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.110556
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.049652
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.106434
#
# Train set: Average loss: 0.0845
# Validation set: Average loss: 0.1427, Accuracy: 9582/10000 (96%)
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.161464
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.024113
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.109462
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.087150
#
# Train set: Average loss: 0.0839
# Validation set: Average loss: 0.1417, Accuracy: 9562/10000 (96%)
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.090472
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.052502
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.060001
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.174402
#
# Train set: Average loss: 0.0836
# Validation set: Average loss: 0.1431, Accuracy: 9554/10000 (96%)
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.036036
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.137289
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.085132
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.147624
#
# Train set: Average loss: 0.0834
# Validation set: Average loss: 0.1440, Accuracy: 9582/10000 (96%)
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.173894
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.078393
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.069614
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.048812
#
# Train set: Average loss: 0.0824
# Validation set: Average loss: 0.1450, Accuracy: 9571/10000 (96%)
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.039872
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.087156
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.040260
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.076711
#
# Train set: Average loss: 0.0827
# Validation set: Average loss: 0.1389, Accuracy: 9598/10000 (96%)
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.141248
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.059585
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.066026
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.094498
#
# Train set: Average loss: 0.0821
# Validation set: Average loss: 0.1408, Accuracy: 9581/10000 (96%)
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.077218
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.059419
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.035574
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.078067
#
# Train set: Average loss: 0.0810
# Validation set: Average loss: 0.1434, Accuracy: 9576/10000 (96%)
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.086401
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.083645
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.085328
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.050650
#
# Train set: Average loss: 0.0817
# Validation set: Average loss: 0.1428, Accuracy: 9582/10000 (96%)
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.044661
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.084665
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.121265
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.191542
#
# Train set: Average loss: 0.0822
# Validation set: Average loss: 0.1443, Accuracy: 9578/10000 (96%)
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.054676
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.133321
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.125364
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.102101
#
# Train set: Average loss: 0.0817
# Validation set: Average loss: 0.1344, Accuracy: 9595/10000 (96%)
# Test set: Average loss: 0.1279, Accuracy: 9621/10000 (96%)

# %% [markdown]
# 3. Compare these results with a deep convolutional network, which is more useful in real-world problems:

# %%
# Compare these results with a deep convolutional network, which is more useful in real-world problems:
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = CNN().to(device)

optimizer = optim.SGD(model.parameters(), lr=model_args['lr'], momentum=model_args['momentum'])
#optimizer = optim.Adadelta(model.parameters(), lr=model_args['lr'])

torch.manual_seed(model_args['seed'])
train_loss = []
validation_loss = []
for epoch_number in range(1, model_args['epochs'] + 1):
    train_loss.append(train(model, device, train_loader, optimizer, epoch_number))
    validation_loss.append(test(model, device, validation_loader, 'Validation set'))

test(model, device, test_loader, 'Test set')
plot_loss(train_loss, validation_loss, 'CNN model')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.314334
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 1.412684
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.949917
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.781365
#
# Train set: Average loss: 1.2327
# Validation set: Average loss: 0.4147, Accuracy: 8606/10000 (86%)
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.788154
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.838174
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.632393
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.596887
#
# Train set: Average loss: 0.6883
# Validation set: Average loss: 0.2494, Accuracy: 9267/10000 (93%)
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.656606
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.616130
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.450954
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.593628
#
# Train set: Average loss: 0.5839
# Validation set: Average loss: 0.2096, Accuracy: 9366/10000 (94%)
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.559622
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.496573
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.484115
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.567977
#
# Train set: Average loss: 0.5345
# Validation set: Average loss: 0.1896, Accuracy: 9405/10000 (94%)
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.585721
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.547646
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.467199
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.372428
#
# Train set: Average loss: 0.5132
# Validation set: Average loss: 0.1635, Accuracy: 9526/10000 (95%)
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.619733
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.474716
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.529984
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.384621
#
# Train set: Average loss: 0.5004
# Validation set: Average loss: 0.1933, Accuracy: 9427/10000 (94%)
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.608861
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.575303
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.364819
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.467888
#
# Train set: Average loss: 0.4935
# Validation set: Average loss: 0.1710, Accuracy: 9498/10000 (95%)
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.489073
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.548339
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.460404
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.567269
#
# Train set: Average loss: 0.4792
# Validation set: Average loss: 0.1629, Accuracy: 9493/10000 (95%)
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.449546
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.436085
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.629379
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.363288
#
# Train set: Average loss: 0.4720
# Validation set: Average loss: 0.1569, Accuracy: 9532/10000 (95%)
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.344801
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.416860
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.520239
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.489425
#
# Train set: Average loss: 0.4688
# Validation set: Average loss: 0.1635, Accuracy: 9527/10000 (95%)
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.391116
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.404568
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.448746
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.422337
#
# Train set: Average loss: 0.4606
# Validation set: Average loss: 0.1531, Accuracy: 9520/10000 (95%)
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.516779
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.484016
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.459270
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.383565
#
# Train set: Average loss: 0.4588
# Validation set: Average loss: 0.1472, Accuracy: 9566/10000 (96%)
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.382834
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.577981
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.451731
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.527991
#
# Train set: Average loss: 0.4580
# Validation set: Average loss: 0.1477, Accuracy: 9549/10000 (95%)
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.291201
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.439844
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.481155
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.428958
#
# Train set: Average loss: 0.4539
# Validation set: Average loss: 0.1503, Accuracy: 9549/10000 (95%)
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.489306
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.588015
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.491684
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.491711
#
# Train set: Average loss: 0.4471
# Validation set: Average loss: 0.1716, Accuracy: 9504/10000 (95%)
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.507344
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.402723
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.414901
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.537183
#
# Train set: Average loss: 0.4424
# Validation set: Average loss: 0.1476, Accuracy: 9543/10000 (95%)
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.471094
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.435678
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.399655
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.591277
#
# Train set: Average loss: 0.4373
# Validation set: Average loss: 0.1466, Accuracy: 9549/10000 (95%)
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.422581
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.276008
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.459393
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.398364
#
# Train set: Average loss: 0.4412
# Validation set: Average loss: 0.1444, Accuracy: 9562/10000 (96%)
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.355794
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.456680
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.298862
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.401741
#
# Train set: Average loss: 0.4332
# Validation set: Average loss: 0.1477, Accuracy: 9545/10000 (95%)
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.283408
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.391087
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.377618
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.371168
#
# Train set: Average loss: 0.4338
# Validation set: Average loss: 0.1504, Accuracy: 9540/10000 (95%)
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.442994
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.256110
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.328820
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.352492
#
# Train set: Average loss: 0.4316
# Validation set: Average loss: 0.1498, Accuracy: 9581/10000 (96%)
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.320693
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.533471
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.396504
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.629079
#
# Train set: Average loss: 0.4239
# Validation set: Average loss: 0.1376, Accuracy: 9600/10000 (96%)
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.296977
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.497649
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.358165
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.417935
#
# Train set: Average loss: 0.4225
# Validation set: Average loss: 0.1429, Accuracy: 9580/10000 (96%)
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.623996
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.263244
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.424450
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.368504
#
# Train set: Average loss: 0.4304
# Validation set: Average loss: 0.1413, Accuracy: 9574/10000 (96%)
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.359011
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.462866
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.550477
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.493640
#
# Train set: Average loss: 0.4255
# Validation set: Average loss: 0.1450, Accuracy: 9556/10000 (96%)
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.425832
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.328186
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.558446
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.379194
#
# Train set: Average loss: 0.4226
# Validation set: Average loss: 0.1372, Accuracy: 9578/10000 (96%)
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.487572
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.463607
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.465354
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.423969
#
# Train set: Average loss: 0.4244
# Validation set: Average loss: 0.1499, Accuracy: 9583/10000 (96%)
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.547308
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.408363
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.541428
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.416657
#
# Train set: Average loss: 0.4197
# Validation set: Average loss: 0.1481, Accuracy: 9578/10000 (96%)
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.486651
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.317728
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.444502
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.385166
#
# Train set: Average loss: 0.4218
# Validation set: Average loss: 0.1544, Accuracy: 9527/10000 (95%)
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.485311
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.363489
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.322088
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.322659
#
# Train set: Average loss: 0.4269
# Validation set: Average loss: 0.1412, Accuracy: 9580/10000 (96%)
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.404979
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.325598
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.322343
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.509388
#
# Train set: Average loss: 0.4146
# Validation set: Average loss: 0.1487, Accuracy: 9562/10000 (96%)
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.425183
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.441126
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.422412
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.469569
#
# Train set: Average loss: 0.4230
# Validation set: Average loss: 0.1334, Accuracy: 9598/10000 (96%)
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.418476
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.414767
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.505004
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.496824
#
# Train set: Average loss: 0.4258
# Validation set: Average loss: 0.1400, Accuracy: 9572/10000 (96%)
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.512572
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.454317
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.589294
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.281611
#
# Train set: Average loss: 0.4207
# Validation set: Average loss: 0.1346, Accuracy: 9590/10000 (96%)
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.386880
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.439658
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.371847
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.498285
#
# Train set: Average loss: 0.4228
# Validation set: Average loss: 0.1370, Accuracy: 9583/10000 (96%)
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.615780
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.309740
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.349920
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.381226
#
# Train set: Average loss: 0.4224
# Validation set: Average loss: 0.1442, Accuracy: 9567/10000 (96%)
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.470313
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.434553
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.397211
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.356897
#
# Train set: Average loss: 0.4207
# Validation set: Average loss: 0.1336, Accuracy: 9595/10000 (96%)
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.403379
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.335642
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.371325
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.527659
#
# Train set: Average loss: 0.4154
# Validation set: Average loss: 0.1550, Accuracy: 9555/10000 (96%)
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.327708
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.327710
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.356888
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.527731
#
# Train set: Average loss: 0.4123
# Validation set: Average loss: 0.1466, Accuracy: 9560/10000 (96%)
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.487531
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.367136
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.566729
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.513788
#
# Train set: Average loss: 0.4122
# Validation set: Average loss: 0.1435, Accuracy: 9581/10000 (96%)
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.499540
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.388892
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.341290
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.688299
#
# Train set: Average loss: 0.4176
# Validation set: Average loss: 0.1427, Accuracy: 9563/10000 (96%)
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.448462
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.427375
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.389677
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.433275
#
# Train set: Average loss: 0.4167
# Validation set: Average loss: 0.1362, Accuracy: 9603/10000 (96%)
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.286245
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.447882
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.343392
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.333942
#
# Train set: Average loss: 0.4124
# Validation set: Average loss: 0.1282, Accuracy: 9619/10000 (96%)
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.395660
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.283956
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.348108
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.425828
#
# Train set: Average loss: 0.4139
# Validation set: Average loss: 0.1378, Accuracy: 9592/10000 (96%)
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.408472
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.294823
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.376824
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.666529
#
# Train set: Average loss: 0.4095
# Validation set: Average loss: 0.1379, Accuracy: 9592/10000 (96%)
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.619524
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.410286
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.365966
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.334928
#
# Train set: Average loss: 0.4149
# Validation set: Average loss: 0.1350, Accuracy: 9604/10000 (96%)
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.571023
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.375803
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.265127
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.323167
#
# Train set: Average loss: 0.4132
# Validation set: Average loss: 0.1333, Accuracy: 9601/10000 (96%)
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.345650
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.370158
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.570345
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.538860
#
# Train set: Average loss: 0.4155
# Validation set: Average loss: 0.1372, Accuracy: 9584/10000 (96%)
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.383346
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.328390
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.457770
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.452556
#
# Train set: Average loss: 0.4108
# Validation set: Average loss: 0.1410, Accuracy: 9581/10000 (96%)
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.299120
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.282961
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.396446
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.449361
#
# Train set: Average loss: 0.4157
# Validation set: Average loss: 0.1311, Accuracy: 9609/10000 (96%)
# Test set: Average loss: 0.1142, Accuracy: 9663/10000 (97%)

# %% [markdown]
# ## Summary
# * *Deep* and *CNN* models with accuracies of 96% and 97% (evaluated on the test subset) perform much better than single-layer *Perceptron* with 92%;
# * The two smallest (and simplest) models appear to be overfitted. To deal with this we need to apply some regularization.
# * Validation subset is evaluated during the training (as opposed to test set, infered *after* the training) in order to tune the model hiperparameters (that describe e.g. the network structure, or training details).
# * A moment to stop trainning is a kind of hipermarameter -- by applying *early stopping* we can avoid overfitting.

# %% [markdown]
# ## Tasks to do
# * apply some regularization technique to *Deep* model in order to avoid overfitting (start with nonzero *weight_decay* in optimizer) -> done in the usage of the class
# * try to figure out why the validation loss for *CNN* model turns to be *lower* than the train loss (hint: turn off regularization),
# * **tune one of these models to get the *Test Set Accuracy* > 99%**,
# * plot the *confusion matrix* among all of the classes---which of digits are mostly confused with each other?
# >How to build the confusion matrix?
# > * for example 1st row represents images with "0" digit (*ground truth*), while 1st colum images for which the model *predicts* "0",
# > * this way element _11 is equal to number of images with "0" corectly clasified as "0" (true positives), while _15 means number of images with "0" wrongly calssified as "4", and so on.

# %% [markdown]
# # Solutions

# %% [markdown]
#  ### Try to figure out why the validation loss for *CNN* model turns to be *lower* than the train loss (hint: turn off regularization)
#
# When the validation loss is lower than the training loss, it often indicates that regularization (such as dropout) is applied during training but not during evaluation. Dropout layers, for example, are active during training to prevent overfitting but are turned off during evaluation, making the model perform better on validation data.

# %% [markdown]
# ### Tune one of these models to get the *Test Set Accuracy* > 99%
#
# Trying with improved CNN:

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

def test_cm(model, device, test_loader, message):
    model.eval()
    test_loss = 0.
    correct = 0
    all_preds = []
    all_targets = []
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='mean').item()
            prediction = output.argmax(dim=1)
            correct += prediction.eq(target).sum().item()
            all_preds.extend(prediction.cpu().numpy())
            all_targets.extend(target.cpu().numpy())
    test_loss /= len(test_loader)
    print('{}: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        message, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss, all_preds, all_targets

def plot_confusion_matrix(cm, classes):
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.title('Confusion Matrix')
    plt.show()

# %%
model_args = {}
model_args['seed'] = 123
model_args['batch_size'] = 128
model_args['lr'] = 1e-4           # changed learning rate from 0.05
model_args['momentum'] = .5
model_args['epochs'] = 50
model_args['log_interval'] = 50   # lower logging frequency -> from 100 to 50

# %%
class ImprovedCNN(nn.Module):
    # this defines the structure of the CNN model
    def __init__(self):
        super(ImprovedCNN, self).__init__()
        # convolutional layer with 2 kernels of size 5x5
        self.conv1 = nn.Conv2d(1, 32, kernel_size=5)
        # 4 kernels of size 5x5
        self.conv2 = nn.Conv2d(32, 64, kernel_size=5)
        # 2D dropout
        self.conv2_drop = nn.Dropout2d()
        # fully connected layers
        self.fc1 = nn.Linear(64*4*4, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        # 1st layers group
        x = self.conv1(x) # resulting in 2 feature maps each of size 24x24
        x = F.max_pool2d(x, 2) # downsizing each map to 12x12
        x = F.relu(x) # standard (in CNNs) ReLU activation
        # 2nd group
        x = self.conv2(x) # resulting in 4 feature maps each of size 8x8
        # x = self.conv2_drop(x)
        x = F.max_pool2d(x, 2) # downsizing each map to 4x4
        x = F.relu(x)
        # fully connected layers
        x = x.view(-1, 64*4*4) # 64 maps of 4x4 size gives 64 numbers
        x = self.fc1(x) # 64 -> 20
        x = F.relu(x)
        x = F.dropout(x, training=self.training) # dropout is a type of regularization
        x = self.fc2(x) # 20 -> 10
        # softmax (multinomial classification) gives probabilities of each class
        return F.log_softmax(x, dim=1) # note that dim=0 is the number of samples in batch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = ImprovedCNN().to(device)

optimizer = torch.optim.Adam(model.parameters(), model_args['lr'])

torch.manual_seed(model_args['seed'])
train_loss = []
validation_loss = []
for epoch_number in range(1, model_args['epochs'] + 1):
    train_loss.append(train(model, device, train_loader, optimizer, epoch_number))
    validation_loss.append(test(model, device, validation_loader, 'Validation set'))

test_loss, test_preds, test_targets = test_cm(model, device, test_loader, 'Test set')
plot_loss(train_loss, validation_loss, 'Improved CNN Model')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.300975
# Train Epoch: 1 [6400/50000 (13%)]	Loss: 1.635837
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 0.948478
# Train Epoch: 1 [19200/50000 (38%)]	Loss: 0.632588
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.495157
# Train Epoch: 1 [32000/50000 (64%)]	Loss: 0.333887
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.389372
# Train Epoch: 1 [44800/50000 (90%)]	Loss: 0.306724
#
# Train set: Average loss: 0.7539
# Validation set: Average loss: 0.2000, Accuracy: 9453/10000 (95%)
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.297936
# Train Epoch: 2 [6400/50000 (13%)]	Loss: 0.197222
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.231163
# Train Epoch: 2 [19200/50000 (38%)]	Loss: 0.099438
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.245049
# Train Epoch: 2 [32000/50000 (64%)]	Loss: 0.186418
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.167265
# Train Epoch: 2 [44800/50000 (90%)]	Loss: 0.198635
#
# Train set: Average loss: 0.2244
# Validation set: Average loss: 0.1217, Accuracy: 9639/10000 (96%)
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.134969
# Train Epoch: 3 [6400/50000 (13%)]	Loss: 0.231795
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.131326
# Train Epoch: 3 [19200/50000 (38%)]	Loss: 0.177179
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.093329
# Train Epoch: 3 [32000/50000 (64%)]	Loss: 0.155435
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.226939
# Train Epoch: 3 [44800/50000 (90%)]	Loss: 0.199885
#
# Train set: Average loss: 0.1531
# Validation set: Average loss: 0.0913, Accuracy: 9720/10000 (97%)
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.106082
# Train Epoch: 4 [6400/50000 (13%)]	Loss: 0.173687
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.118564
# Train Epoch: 4 [19200/50000 (38%)]	Loss: 0.084393
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.124539
# Train Epoch: 4 [32000/50000 (64%)]	Loss: 0.146892
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.097884
# Train Epoch: 4 [44800/50000 (90%)]	Loss: 0.114217
#
# Train set: Average loss: 0.1223
# Validation set: Average loss: 0.0779, Accuracy: 9764/10000 (98%)
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.193223
# Train Epoch: 5 [6400/50000 (13%)]	Loss: 0.123967
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.068810
# Train Epoch: 5 [19200/50000 (38%)]	Loss: 0.113707
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.086667
# Train Epoch: 5 [32000/50000 (64%)]	Loss: 0.052542
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.060610
# Train Epoch: 5 [44800/50000 (90%)]	Loss: 0.068915
#
# Train set: Average loss: 0.1048
# Validation set: Average loss: 0.0687, Accuracy: 9786/10000 (98%)
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.191452
# Train Epoch: 6 [6400/50000 (13%)]	Loss: 0.069872
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.089994
# Train Epoch: 6 [19200/50000 (38%)]	Loss: 0.127668
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.051970
# Train Epoch: 6 [32000/50000 (64%)]	Loss: 0.056363
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.092268
# Train Epoch: 6 [44800/50000 (90%)]	Loss: 0.140469
#
# Train set: Average loss: 0.0925
# Validation set: Average loss: 0.0606, Accuracy: 9817/10000 (98%)
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.094622
# Train Epoch: 7 [6400/50000 (13%)]	Loss: 0.082463
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.086030
# Train Epoch: 7 [19200/50000 (38%)]	Loss: 0.074689
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.230315
# Train Epoch: 7 [32000/50000 (64%)]	Loss: 0.074322
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.062777
# Train Epoch: 7 [44800/50000 (90%)]	Loss: 0.120209
#
# Train set: Average loss: 0.0832
# Validation set: Average loss: 0.0545, Accuracy: 9825/10000 (98%)
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.041334
# Train Epoch: 8 [6400/50000 (13%)]	Loss: 0.053131
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.039557
# Train Epoch: 8 [19200/50000 (38%)]	Loss: 0.119617
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.094146
# Train Epoch: 8 [32000/50000 (64%)]	Loss: 0.052868
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.110661
# Train Epoch: 8 [44800/50000 (90%)]	Loss: 0.127030
#
# Train set: Average loss: 0.0738
# Validation set: Average loss: 0.0529, Accuracy: 9829/10000 (98%)
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.093053
# Train Epoch: 9 [6400/50000 (13%)]	Loss: 0.093555
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.046873
# Train Epoch: 9 [19200/50000 (38%)]	Loss: 0.075012
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.037855
# Train Epoch: 9 [32000/50000 (64%)]	Loss: 0.088502
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.079464
# Train Epoch: 9 [44800/50000 (90%)]	Loss: 0.106401
#
# Train set: Average loss: 0.0684
# Validation set: Average loss: 0.0497, Accuracy: 9853/10000 (99%)
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.018392
# Train Epoch: 10 [6400/50000 (13%)]	Loss: 0.082843
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.114735
# Train Epoch: 10 [19200/50000 (38%)]	Loss: 0.081757
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.069537
# Train Epoch: 10 [32000/50000 (64%)]	Loss: 0.073573
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.049845
# Train Epoch: 10 [44800/50000 (90%)]	Loss: 0.037693
#
# Train set: Average loss: 0.0612
# Validation set: Average loss: 0.0465, Accuracy: 9850/10000 (98%)
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.084004
# Train Epoch: 11 [6400/50000 (13%)]	Loss: 0.068595
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.030486
# Train Epoch: 11 [19200/50000 (38%)]	Loss: 0.050890
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.099670
# Train Epoch: 11 [32000/50000 (64%)]	Loss: 0.018591
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.045538
# Train Epoch: 11 [44800/50000 (90%)]	Loss: 0.064823
#
# Train set: Average loss: 0.0591
# Validation set: Average loss: 0.0452, Accuracy: 9859/10000 (99%)
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.034326
# Train Epoch: 12 [6400/50000 (13%)]	Loss: 0.066295
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.058667
# Train Epoch: 12 [19200/50000 (38%)]	Loss: 0.034756
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.051201
# Train Epoch: 12 [32000/50000 (64%)]	Loss: 0.057173
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.053863
# Train Epoch: 12 [44800/50000 (90%)]	Loss: 0.063007
#
# Train set: Average loss: 0.0538
# Validation set: Average loss: 0.0421, Accuracy: 9870/10000 (99%)
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.051343
# Train Epoch: 13 [6400/50000 (13%)]	Loss: 0.019187
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.041057
# Train Epoch: 13 [19200/50000 (38%)]	Loss: 0.071631
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.088519
# Train Epoch: 13 [32000/50000 (64%)]	Loss: 0.018379
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.071156
# Train Epoch: 13 [44800/50000 (90%)]	Loss: 0.079592
#
# Train set: Average loss: 0.0520
# Validation set: Average loss: 0.0404, Accuracy: 9868/10000 (99%)
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.090984
# Train Epoch: 14 [6400/50000 (13%)]	Loss: 0.014310
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.018909
# Train Epoch: 14 [19200/50000 (38%)]	Loss: 0.058107
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.054105
# Train Epoch: 14 [32000/50000 (64%)]	Loss: 0.026889
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.032885
# Train Epoch: 14 [44800/50000 (90%)]	Loss: 0.023324
#
# Train set: Average loss: 0.0490
# Validation set: Average loss: 0.0468, Accuracy: 9867/10000 (99%)
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.063903
# Train Epoch: 15 [6400/50000 (13%)]	Loss: 0.057822
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.075466
# Train Epoch: 15 [19200/50000 (38%)]	Loss: 0.027530
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.035417
# Train Epoch: 15 [32000/50000 (64%)]	Loss: 0.016131
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.075120
# Train Epoch: 15 [44800/50000 (90%)]	Loss: 0.095217
#
# Train set: Average loss: 0.0461
# Validation set: Average loss: 0.0379, Accuracy: 9876/10000 (99%)
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.022997
# Train Epoch: 16 [6400/50000 (13%)]	Loss: 0.025227
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.065411
# Train Epoch: 16 [19200/50000 (38%)]	Loss: 0.067922
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.060271
# Train Epoch: 16 [32000/50000 (64%)]	Loss: 0.030930
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.098108
# Train Epoch: 16 [44800/50000 (90%)]	Loss: 0.023346
#
# Train set: Average loss: 0.0436
# Validation set: Average loss: 0.0374, Accuracy: 9887/10000 (99%)
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.022947
# Train Epoch: 17 [6400/50000 (13%)]	Loss: 0.061080
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.026191
# Train Epoch: 17 [19200/50000 (38%)]	Loss: 0.014778
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.079934
# Train Epoch: 17 [32000/50000 (64%)]	Loss: 0.015339
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.022552
# Train Epoch: 17 [44800/50000 (90%)]	Loss: 0.083729
#
# Train set: Average loss: 0.0427
# Validation set: Average loss: 0.0351, Accuracy: 9881/10000 (99%)
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.038117
# Train Epoch: 18 [6400/50000 (13%)]	Loss: 0.059639
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.025292
# Train Epoch: 18 [19200/50000 (38%)]	Loss: 0.016652
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.006747
# Train Epoch: 18 [32000/50000 (64%)]	Loss: 0.043808
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.034726
# Train Epoch: 18 [44800/50000 (90%)]	Loss: 0.012388
#
# Train set: Average loss: 0.0388
# Validation set: Average loss: 0.0425, Accuracy: 9883/10000 (99%)
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.026484
# Train Epoch: 19 [6400/50000 (13%)]	Loss: 0.015963
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.006802
# Train Epoch: 19 [19200/50000 (38%)]	Loss: 0.010505
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.013327
# Train Epoch: 19 [32000/50000 (64%)]	Loss: 0.075574
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.021656
# Train Epoch: 19 [44800/50000 (90%)]	Loss: 0.048912
#
# Train set: Average loss: 0.0363
# Validation set: Average loss: 0.0322, Accuracy: 9896/10000 (99%)
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.055957
# Train Epoch: 20 [6400/50000 (13%)]	Loss: 0.010213
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.044012
# Train Epoch: 20 [19200/50000 (38%)]	Loss: 0.041548
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.057759
# Train Epoch: 20 [32000/50000 (64%)]	Loss: 0.014052
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.037802
# Train Epoch: 20 [44800/50000 (90%)]	Loss: 0.025308
#
# Train set: Average loss: 0.0347
# Validation set: Average loss: 0.0321, Accuracy: 9886/10000 (99%)
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.006771
# Train Epoch: 21 [6400/50000 (13%)]	Loss: 0.006826
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.073344
# Train Epoch: 21 [19200/50000 (38%)]	Loss: 0.004630
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.018680
# Train Epoch: 21 [32000/50000 (64%)]	Loss: 0.072094
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.017610
# Train Epoch: 21 [44800/50000 (90%)]	Loss: 0.027814
#
# Train set: Average loss: 0.0325
# Validation set: Average loss: 0.0309, Accuracy: 9898/10000 (99%)
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.089999
# Train Epoch: 22 [6400/50000 (13%)]	Loss: 0.019389
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.021435
# Train Epoch: 22 [19200/50000 (38%)]	Loss: 0.019473
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.096250
# Train Epoch: 22 [32000/50000 (64%)]	Loss: 0.029724
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.030657
# Train Epoch: 22 [44800/50000 (90%)]	Loss: 0.009387
#
# Train set: Average loss: 0.0300
# Validation set: Average loss: 0.0327, Accuracy: 9893/10000 (99%)
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.016953
# Train Epoch: 23 [6400/50000 (13%)]	Loss: 0.010047
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.025356
# Train Epoch: 23 [19200/50000 (38%)]	Loss: 0.019283
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.014348
# Train Epoch: 23 [32000/50000 (64%)]	Loss: 0.061839
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.020016
# Train Epoch: 23 [44800/50000 (90%)]	Loss: 0.007903
#
# Train set: Average loss: 0.0303
# Validation set: Average loss: 0.0322, Accuracy: 9891/10000 (99%)
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.026256
# Train Epoch: 24 [6400/50000 (13%)]	Loss: 0.022424
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.023942
# Train Epoch: 24 [19200/50000 (38%)]	Loss: 0.025668
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.004535
# Train Epoch: 24 [32000/50000 (64%)]	Loss: 0.015232
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.022483
# Train Epoch: 24 [44800/50000 (90%)]	Loss: 0.026595
#
# Train set: Average loss: 0.0286
# Validation set: Average loss: 0.0300, Accuracy: 9899/10000 (99%)
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.015102
# Train Epoch: 25 [6400/50000 (13%)]	Loss: 0.009675
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.018950
# Train Epoch: 25 [19200/50000 (38%)]	Loss: 0.033377
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.047592
# Train Epoch: 25 [32000/50000 (64%)]	Loss: 0.044615
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.023918
# Train Epoch: 25 [44800/50000 (90%)]	Loss: 0.022881
#
# Train set: Average loss: 0.0271
# Validation set: Average loss: 0.0341, Accuracy: 9904/10000 (99%)
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.011729
# Train Epoch: 26 [6400/50000 (13%)]	Loss: 0.005931
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.029710
# Train Epoch: 26 [19200/50000 (38%)]	Loss: 0.037097
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.017043
# Train Epoch: 26 [32000/50000 (64%)]	Loss: 0.032177
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.012993
# Train Epoch: 26 [44800/50000 (90%)]	Loss: 0.036323
#
# Train set: Average loss: 0.0265
# Validation set: Average loss: 0.0292, Accuracy: 9919/10000 (99%)
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.018409
# Train Epoch: 27 [6400/50000 (13%)]	Loss: 0.058654
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.011527
# Train Epoch: 27 [19200/50000 (38%)]	Loss: 0.010864
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.018402
# Train Epoch: 27 [32000/50000 (64%)]	Loss: 0.022292
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.008505
# Train Epoch: 27 [44800/50000 (90%)]	Loss: 0.011994
#
# Train set: Average loss: 0.0243
# Validation set: Average loss: 0.0311, Accuracy: 9900/10000 (99%)
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.025902
# Train Epoch: 28 [6400/50000 (13%)]	Loss: 0.037548
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.026333
# Train Epoch: 28 [19200/50000 (38%)]	Loss: 0.005416
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.008572
# Train Epoch: 28 [32000/50000 (64%)]	Loss: 0.050035
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.034192
# Train Epoch: 28 [44800/50000 (90%)]	Loss: 0.030175
#
# Train set: Average loss: 0.0235
# Validation set: Average loss: 0.0306, Accuracy: 9907/10000 (99%)
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.008140
# Train Epoch: 29 [6400/50000 (13%)]	Loss: 0.065844
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.048609
# Train Epoch: 29 [19200/50000 (38%)]	Loss: 0.004543
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.004674
# Train Epoch: 29 [32000/50000 (64%)]	Loss: 0.021376
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.007402
# Train Epoch: 29 [44800/50000 (90%)]	Loss: 0.028465
#
# Train set: Average loss: 0.0232
# Validation set: Average loss: 0.0304, Accuracy: 9903/10000 (99%)
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.017394
# Train Epoch: 30 [6400/50000 (13%)]	Loss: 0.038290
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.023103
# Train Epoch: 30 [19200/50000 (38%)]	Loss: 0.039760
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.026242
# Train Epoch: 30 [32000/50000 (64%)]	Loss: 0.009215
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.015975
# Train Epoch: 30 [44800/50000 (90%)]	Loss: 0.013777
#
# Train set: Average loss: 0.0211
# Validation set: Average loss: 0.0326, Accuracy: 9909/10000 (99%)
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.024890
# Train Epoch: 31 [6400/50000 (13%)]	Loss: 0.035600
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.006107
# Train Epoch: 31 [19200/50000 (38%)]	Loss: 0.014699
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.015007
# Train Epoch: 31 [32000/50000 (64%)]	Loss: 0.022668
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.024647
# Train Epoch: 31 [44800/50000 (90%)]	Loss: 0.021083
#
# Train set: Average loss: 0.0214
# Validation set: Average loss: 0.0289, Accuracy: 9908/10000 (99%)
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.008088
# Train Epoch: 32 [6400/50000 (13%)]	Loss: 0.093898
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.024731
# Train Epoch: 32 [19200/50000 (38%)]	Loss: 0.008466
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.006298
# Train Epoch: 32 [32000/50000 (64%)]	Loss: 0.003467
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.016098
# Train Epoch: 32 [44800/50000 (90%)]	Loss: 0.002958
#
# Train set: Average loss: 0.0192
# Validation set: Average loss: 0.0293, Accuracy: 9905/10000 (99%)
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.002656
# Train Epoch: 33 [6400/50000 (13%)]	Loss: 0.045810
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.060208
# Train Epoch: 33 [19200/50000 (38%)]	Loss: 0.044209
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.012618
# Train Epoch: 33 [32000/50000 (64%)]	Loss: 0.004790
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.013273
# Train Epoch: 33 [44800/50000 (90%)]	Loss: 0.006152
#
# Train set: Average loss: 0.0195
# Validation set: Average loss: 0.0276, Accuracy: 9915/10000 (99%)
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.009199
# Train Epoch: 34 [6400/50000 (13%)]	Loss: 0.024809
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.013806
# Train Epoch: 34 [19200/50000 (38%)]	Loss: 0.015771
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.046646
# Train Epoch: 34 [32000/50000 (64%)]	Loss: 0.009449
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.005793
# Train Epoch: 34 [44800/50000 (90%)]	Loss: 0.022194
#
# Train set: Average loss: 0.0184
# Validation set: Average loss: 0.0280, Accuracy: 9902/10000 (99%)
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.013128
# Train Epoch: 35 [6400/50000 (13%)]	Loss: 0.047389
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.005967
# Train Epoch: 35 [19200/50000 (38%)]	Loss: 0.005866
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.006672
# Train Epoch: 35 [32000/50000 (64%)]	Loss: 0.009077
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.003840
# Train Epoch: 35 [44800/50000 (90%)]	Loss: 0.004792
#
# Train set: Average loss: 0.0178
# Validation set: Average loss: 0.0280, Accuracy: 9915/10000 (99%)
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.007048
# Train Epoch: 36 [6400/50000 (13%)]	Loss: 0.065629
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.002626
# Train Epoch: 36 [19200/50000 (38%)]	Loss: 0.002186
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.013735
# Train Epoch: 36 [32000/50000 (64%)]	Loss: 0.015206
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.017511
# Train Epoch: 36 [44800/50000 (90%)]	Loss: 0.008174
#
# Train set: Average loss: 0.0165
# Validation set: Average loss: 0.0279, Accuracy: 9916/10000 (99%)
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.022866
# Train Epoch: 37 [6400/50000 (13%)]	Loss: 0.020693
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.013558
# Train Epoch: 37 [19200/50000 (38%)]	Loss: 0.014108
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.002741
# Train Epoch: 37 [32000/50000 (64%)]	Loss: 0.018194
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.006192
# Train Epoch: 37 [44800/50000 (90%)]	Loss: 0.006148
#
# Train set: Average loss: 0.0155
# Validation set: Average loss: 0.0284, Accuracy: 9907/10000 (99%)
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.033653
# Train Epoch: 38 [6400/50000 (13%)]	Loss: 0.019848
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.005371
# Train Epoch: 38 [19200/50000 (38%)]	Loss: 0.015667
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.008008
# Train Epoch: 38 [32000/50000 (64%)]	Loss: 0.004212
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.016969
# Train Epoch: 38 [44800/50000 (90%)]	Loss: 0.003598
#
# Train set: Average loss: 0.0149
# Validation set: Average loss: 0.0291, Accuracy: 9915/10000 (99%)
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.009149
# Train Epoch: 39 [6400/50000 (13%)]	Loss: 0.002666
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.008471
# Train Epoch: 39 [19200/50000 (38%)]	Loss: 0.003365
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.012551
# Train Epoch: 39 [32000/50000 (64%)]	Loss: 0.014934
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.013592
# Train Epoch: 39 [44800/50000 (90%)]	Loss: 0.003088
#
# Train set: Average loss: 0.0143
# Validation set: Average loss: 0.0286, Accuracy: 9917/10000 (99%)
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.006964
# Train Epoch: 40 [6400/50000 (13%)]	Loss: 0.023506
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.060668
# Train Epoch: 40 [19200/50000 (38%)]	Loss: 0.013780
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.020105
# Train Epoch: 40 [32000/50000 (64%)]	Loss: 0.003309
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.061706
# Train Epoch: 40 [44800/50000 (90%)]	Loss: 0.027844
#
# Train set: Average loss: 0.0145
# Validation set: Average loss: 0.0273, Accuracy: 9921/10000 (99%)
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.011853
# Train Epoch: 41 [6400/50000 (13%)]	Loss: 0.059365
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.001765
# Train Epoch: 41 [19200/50000 (38%)]	Loss: 0.052550
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.013636
# Train Epoch: 41 [32000/50000 (64%)]	Loss: 0.008255
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.003945
# Train Epoch: 41 [44800/50000 (90%)]	Loss: 0.019158
#
# Train set: Average loss: 0.0130
# Validation set: Average loss: 0.0278, Accuracy: 9919/10000 (99%)
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.045266
# Train Epoch: 42 [6400/50000 (13%)]	Loss: 0.014055
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.002496
# Train Epoch: 42 [19200/50000 (38%)]	Loss: 0.007250
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.004204
# Train Epoch: 42 [32000/50000 (64%)]	Loss: 0.030287
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.002515
# Train Epoch: 42 [44800/50000 (90%)]	Loss: 0.048696
#
# Train set: Average loss: 0.0126
# Validation set: Average loss: 0.0270, Accuracy: 9921/10000 (99%)
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.014565
# Train Epoch: 43 [6400/50000 (13%)]	Loss: 0.052498
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.011180
# Train Epoch: 43 [19200/50000 (38%)]	Loss: 0.033826
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.007209
# Train Epoch: 43 [32000/50000 (64%)]	Loss: 0.001750
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.009038
# Train Epoch: 43 [44800/50000 (90%)]	Loss: 0.011302
#
# Train set: Average loss: 0.0125
# Validation set: Average loss: 0.0285, Accuracy: 9917/10000 (99%)
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.003734
# Train Epoch: 44 [6400/50000 (13%)]	Loss: 0.003770
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.024540
# Train Epoch: 44 [19200/50000 (38%)]	Loss: 0.015781
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.001082
# Train Epoch: 44 [32000/50000 (64%)]	Loss: 0.007175
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.006437
# Train Epoch: 44 [44800/50000 (90%)]	Loss: 0.006527
#
# Train set: Average loss: 0.0120
# Validation set: Average loss: 0.0317, Accuracy: 9912/10000 (99%)
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.004118
# Train Epoch: 45 [6400/50000 (13%)]	Loss: 0.052682
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.004240
# Train Epoch: 45 [19200/50000 (38%)]	Loss: 0.000685
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.001414
# Train Epoch: 45 [32000/50000 (64%)]	Loss: 0.048889
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.017427
# Train Epoch: 45 [44800/50000 (90%)]	Loss: 0.038737
#
# Train set: Average loss: 0.0119
# Validation set: Average loss: 0.0310, Accuracy: 9914/10000 (99%)
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.000806
# Train Epoch: 46 [6400/50000 (13%)]	Loss: 0.009644
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.031298
# Train Epoch: 46 [19200/50000 (38%)]	Loss: 0.009671
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.004268
# Train Epoch: 46 [32000/50000 (64%)]	Loss: 0.019746
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.004445
# Train Epoch: 46 [44800/50000 (90%)]	Loss: 0.003761
#
# Train set: Average loss: 0.0118
# Validation set: Average loss: 0.0269, Accuracy: 9917/10000 (99%)
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.001803
# Train Epoch: 47 [6400/50000 (13%)]	Loss: 0.044104
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.004929
# Train Epoch: 47 [19200/50000 (38%)]	Loss: 0.007598
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.023817
# Train Epoch: 47 [32000/50000 (64%)]	Loss: 0.001484
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.004354
# Train Epoch: 47 [44800/50000 (90%)]	Loss: 0.003513
#
# Train set: Average loss: 0.0096
# Validation set: Average loss: 0.0270, Accuracy: 9923/10000 (99%)
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.002759
# Train Epoch: 48 [6400/50000 (13%)]	Loss: 0.003763
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.015172
# Train Epoch: 48 [19200/50000 (38%)]	Loss: 0.019670
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.017647
# Train Epoch: 48 [32000/50000 (64%)]	Loss: 0.005652
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.037506
# Train Epoch: 48 [44800/50000 (90%)]	Loss: 0.014702
#
# Train set: Average loss: 0.0104
# Validation set: Average loss: 0.0304, Accuracy: 9915/10000 (99%)
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.008869
# Train Epoch: 49 [6400/50000 (13%)]	Loss: 0.027963
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.002377
# Train Epoch: 49 [19200/50000 (38%)]	Loss: 0.003694
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.001181
# Train Epoch: 49 [32000/50000 (64%)]	Loss: 0.030063
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.021568
# Train Epoch: 49 [44800/50000 (90%)]	Loss: 0.011775
#
# Train set: Average loss: 0.0100
# Validation set: Average loss: 0.0298, Accuracy: 9924/10000 (99%)
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.011562
# Train Epoch: 50 [6400/50000 (13%)]	Loss: 0.002925
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.004558
# Train Epoch: 50 [19200/50000 (38%)]	Loss: 0.001714
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.025549
# Train Epoch: 50 [32000/50000 (64%)]	Loss: 0.012229
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.003311
# Train Epoch: 50 [44800/50000 (90%)]	Loss: 0.000748
#
# Train set: Average loss: 0.0104
# Validation set: Average loss: 0.0284, Accuracy: 9919/10000 (99%)
# Test set: Average loss: 0.0211, Accuracy: 9929/10000 (99%)

# %%
conf_matrix = confusion_matrix(test_targets, test_preds)
plot_confusion_matrix(conf_matrix, classes=[str(i) for i in range(10)])
